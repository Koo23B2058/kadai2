# %%
from numpy import random
from matplotlib import pyplot as plt

I = random.rand(256, 256)

plt.imshow(I, cmap='gray')
plt.show()

# %%
from numpy import random
from matplotlib import pyplot as plt

I = random.rand(256, 256)

plt.imshow(I, cmap='gray')
plt.show()
